# %%
from web_api_kamis import *
kamis_api_check()
# Out:
# <Response [200]>

# %%
import pandas as pd
df = pd.read_csv('/Users/bellepoque7/Documents/GitHub/whereisplanb/kamis api/Data/감자_230408_3yr.csv')
df.describe()
# Out:
#         Unnamed: 0    품목코드         품종코드         상태코드       조회일자 가격  \
# count  2118.000000  2118.0  2118.000000  2118.000000   1640.000000
# mean     16.179887   152.0     1.122757     4.500000  39029.851829
# std       1.206670     0.0     0.328236     0.500118  11402.335808
# min      14.000000   152.0     1.000000     4.000000  17360.000000
# 25%      15.000000   152.0     1.000000     4.000000  31315.000000
# 50%      16.000000   152.0     1.000000     4.500000  37460.000000
# 75%      17.000000   152.0     1.000000     5.000000  44620.000000
# max      19.000000   152.0     2.000000     5.000000  81400.000000
#
#              1일전 가격       1주일전 가격       2주일전 가격      1개월전 가격        1년전 가격  \
# count   1642.000000   1640.000000   1640.000000   1946.00000   1954.000000
# mean   39008.743605  38835.095732  38697.998171  37686.68037  31873.006653
# std    11411.650187  11391.035954  11439.368726  10896.05306  11789.577221
# ...
