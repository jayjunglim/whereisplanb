# %% [markdown]
# ## 일별 부류별 도.소매가격정보
# https://www.kamis.or.kr/customer/reference/openapi_list.do?action=detail&boardno=1

# %%
import requests
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET


url = 'http://www.kamis.or.kr/service/price/xml.do?action=dailyPriceByCategoryList'
params = {
('p_cert_key',''), #인증Key
('p_cert_id','0hmygot@naver.com'),   #요청자id
('p_returntype','xml'), #Return Type (json:Json 데이터 형식, xml:XML데이터형식)
('p_product_cls_code',''), #구분 ( 01:소매, 02:도매, default:02 )
('p_item_category_code',''), # 부류코드(100:식량작물, 200:채소류, 300:특용작물, 400:과일류, 500:축산물, 600:수산물, default:100)
('p_country_code',''), 
#* 소매가격 선택가능 지역 (1101:서울, 2100:부산, 2200:대구, 2300:인천, 2401:광주, 2501:대전, 2601:울산, 3111:수원, 3211:춘천, 3311:청주, 3511:전주, 
# 3711:포항, 3911:제주, 3113:의정부, 3613:순천, 3714:안동, 3814:창원, 3145:용인)
#도매가격 선택가능 지역 (1101:서울, 2100:부산, 2200:대구, 2401:광주, 2501:대전)default : 전체지역
('p_regday','2022-09-15'), # 날짜 : yyyy-mm-dd (default : 최근 조사일자)
('p_convert_kg_yn',''), #kg단위 환산여부(Y : 1kg 단위표시, N : 정보조사 단위표시, ex: 쌀 20kg)default : N
}
response = requests.get(url,params)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <document>
# 	<condition>
# 		<item>
# 			<p_product_cls_code></p_product_cls_code>
# 			<p_country_code></p_country_code>
# 			<p_regday>2022-09-15</p_regday>
# 			<p_convert_kg_yn></p_convert_kg_yn>
# 			<p_category_code>100</p_category_code>
# 			<p_cert_key>e4b30991-cca9-45fc-aec4-3c4e0fa0fe97</p_cert_key>
# 			<p_cert_id>0hmygot@naver.com</p_cert_id>
# 			<p_returntype>xml</p_returntype>
# 		</item>
# 	</condition>
# 	<data>
# 		<error_code>000</error_code>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>안심</kind_name>
# 			<kind_code>21</kind_code>
# 			<rank>1++등급</rank>
# 			<rank_code>01</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>15,633</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>15,629</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>15,628</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>16,758</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>15,442</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>안심</kind_name>
# 			<kind_code>21</kind_code>
# 			<rank>1+등급</rank>
# 			<rank_code>02</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>15,794</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>15,781</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>15,766</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>15,748</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>15,796</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>안심</kind_name>
# 			<kind_code>21</kind_code>
# 			<rank>1등급</rank>
# 			<rank_code>03</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>13,059</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>13,061</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>13,078</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>13,010</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>13,358</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>등심</kind_name>
# 			<kind_code>22</kind_code>
# 			<rank>1++등급</rank>
# 			<rank_code>01</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>13,663</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>13,653</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>13,625</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>13,927</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>13,990</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>등심</kind_name>
# 			<kind_code>22</kind_code>
# 			<rank>1+등급</rank>
# 			<rank_code>02</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>12,857</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>12,858</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>12,656</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>12,375</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>12,622</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>등심</kind_name>
# 			<kind_code>22</kind_code>
# 			<rank>1등급</rank>
# 			<rank_code>03</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>10,140</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>10,143</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>9,986</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>9,859</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>10,272</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>설도</kind_name>
# 			<kind_code>36</kind_code>
# 			<rank>1++등급</rank>
# 			<rank_code>01</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>4,891</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>4,892</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>4,980</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>5,432</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>4,902</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>설도</kind_name>
# 			<kind_code>36</kind_code>
# 			<rank>1+등급</rank>
# 			<rank_code>02</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>4,804</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>4,802</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>4,901</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>4,876</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>5,255</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>설도</kind_name>
# 			<kind_code>36</kind_code>
# 			<rank>1등급</rank>
# 			<rank_code>03</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>4,121</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>4,122</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>4,242</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>4,246</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>4,502</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>양지</kind_name>
# 			<kind_code>40</kind_code>
# 			<rank>1++등급</rank>
# 			<rank_code>01</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>6,542</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>6,549</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>6,574</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>6,794</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>5,973</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>양지</kind_name>
# 			<kind_code>40</kind_code>
# 			<rank>1+등급</rank>
# 			<rank_code>02</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>6,159</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>6,159</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>6,166</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>6,164</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>6,185</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>양지</kind_name>
# 			<kind_code>40</kind_code>
# 			<rank>1등급</rank>
# 			<rank_code>03</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>5,528</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>5,528</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>5,516</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>5,531</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>5,450</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>갈비</kind_name>
# 			<kind_code>50</kind_code>
# 			<rank>1++등급</rank>
# 			<rank_code>01</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>8,174</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>8,137</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>8,082</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>7,152</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>7,516</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>갈비</kind_name>
# 			<kind_code>50</kind_code>
# 			<rank>1+등급</rank>
# 			<rank_code>02</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>6,831</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>6,830</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>6,960</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>6,876</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>6,977</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>소</item_name>
# 			<item_code>4301</item_code>
# 			<kind_name>갈비</kind_name>
# 			<kind_code>50</kind_code>
# 			<rank>1등급</rank>
# 			<rank_code>03</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>6,702</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>6,707</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>6,640</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>6,647</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>6,641</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>돼지</item_name>
# 			<item_code>4304</item_code>
# 			<kind_name>앞다리</kind_name>
# 			<kind_code>25</kind_code>
# 			<rank>앞다리</rank>
# 			<rank_code>00</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>1,403</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>1,402</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>1,382</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>1,382</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>1,301</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>돼지</item_name>
# 			<item_code>4304</item_code>
# 			<kind_name>삼겹살</kind_name>
# 			<kind_code>27</kind_code>
# 			<rank>삼겹살</rank>
# 			<rank_code>00</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>2,623</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>2,623</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>2,618</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>2,813</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>2,631</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>돼지</item_name>
# 			<item_code>4304</item_code>
# 			<kind_name>갈비</kind_name>
# 			<kind_code>28</kind_code>
# 			<rank>갈비</rank>
# 			<rank_code>00</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>1,535</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>1,534</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>1,488</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>1,480</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>1,382</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>돼지</item_name>
# 			<item_code>4304</item_code>
# 			<kind_name>목심</kind_name>
# 			<kind_code>68</kind_code>
# 			<rank>목심</rank>
# 			<rank_code>00</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>2,428</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>2,425</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>2,424</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>2,615</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>2,436</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>수입 소고기</item_name>
# 			<item_code>4401</item_code>
# 			<kind_name>갈비</kind_name>
# 			<kind_code>31</kind_code>
# 			<rank>미국산</rank>
# 			<rank_code>81</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>4,201</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>4,200</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>4,093</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>4,226</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>4,213</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>수입 소고기</item_name>
# 			<item_code>4401</item_code>
# 			<kind_name>갈비</kind_name>
# 			<kind_code>31</kind_code>
# 			<rank>호주산</rank>
# 			<rank_code>82</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>4,361</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>4,361</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>4,334</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>4,319</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>4,545</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>수입 소고기</item_name>
# 			<item_code>4401</item_code>
# 			<kind_name>갈비살</kind_name>
# 			<kind_code>37</kind_code>
# 			<rank>미국산</rank>
# 			<rank_code>81</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>4,426</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>4,431</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>4,405</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>4,158</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>4,388</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>수입 소고기</item_name>
# 			<item_code>4401</item_code>
# 			<kind_name>갈비살</kind_name>
# 			<kind_code>37</kind_code>
# 			<rank>호주산</rank>
# 			<rank_code>82</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>0</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>0</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>0</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>0</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>0</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>수입 돼지고기</item_name>
# 			<item_code>4402</item_code>
# 			<kind_name>삼겹살</kind_name>
# 			<kind_code>27</kind_code>
# 			<rank>삼겹살</rank>
# 			<rank_code>00</rank_code>
# 			<unit>100g</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>1,455</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>1,456</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>1,452</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>1,451</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>1,471</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>닭</item_name>
# 			<item_code>9901</item_code>
# 			<kind_name>육계(kg)</kind_name>
# 			<kind_code>99</kind_code>
# 			<rank>육계(kg)</rank>
# 			<rank_code>00</rank_code>
# 			<unit>1kg</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>5,588</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>5,591</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>5,590</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>5,601</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>5,893</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>계란</item_name>
# 			<item_code>9903</item_code>
# 			<kind_name>특란10구</kind_name>
# 			<kind_code>21</kind_code>
# 			<rank>일반란</rank>
# 			<rank_code>71</rank_code>
# 			<unit>10구</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>3,763</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>3,751</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>3,828</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>3,812</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>3,676</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>계란</item_name>
# 			<item_code>9903</item_code>
# 			<kind_name>특란10구</kind_name>
# 			<kind_code>21</kind_code>
# 			<rank>등급란</rank>
# 			<rank_code>72</rank_code>
# 			<unit>10구</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>5,339</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>5,339</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>5,339</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>5,324</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>5,415</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>계란</item_name>
# 			<item_code>9903</item_code>
# 			<kind_name>특란30구</kind_name>
# 			<kind_code>23</kind_code>
# 			<rank>일반란</rank>
# 			<rank_code>71</rank_code>
# 			<unit>30구</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>6,576</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>6,576</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>6,583</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>6,601</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>6,626</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>계란</item_name>
# 			<item_code>9903</item_code>
# 			<kind_name>특란30구</kind_name>
# 			<kind_code>23</kind_code>
# 			<rank>등급란</rank>
# 			<rank_code>72</rank_code>
# 			<unit>30구</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>8,552</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>8,708</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>8,758</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>9,293</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>9,395</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 		<item>
# 			<item_name>우유</item_name>
# 			<item_code>9908</item_code>
# 			<kind_name>흰우유</kind_name>
# 			<kind_code>01</kind_code>
# 			<rank>흰우유</rank>
# 			<rank_code>00</rank_code>
# 			<unit>1L</unit>
# 			<day1>당일 (09/15)</day1>
# 			<dpr1>2,713</dpr1>
# 			<day2>1일전 (09/14)</day2>
# 			<dpr2>2,714</dpr2>
# 			<day3>1주일전 (09/08)</day3>
# 			<dpr3>2,715</dpr3>
# 			<day4>2주일전 (09/01)</day4>
# 			<dpr4>2,713</dpr4>
# 			<day5>1개월전</day5>
# 			<dpr5>2,709</dpr5>
# 			<day6>1년전</day6>
# 			<dpr6>0</dpr6>
# 			<day7>일평년</day7>
# 			<dpr7>-</dpr7>
# 		</item>
# 	</data>
# </document>

# %%
root = ET.fromstring(response.text)
row_dict = {'item_name':[],'item_code':[],'kind_name':[],'kind_code':[],'rank':[],'rank_code':[],
'unit':[],'day1':[],'dpr1':[],'day2':[],'dpr2':[],'day3':[],'dpr3':[],'day4':[],'dpr4':[],'day5':[],'dpr5':[]
,'day6':[],'dpr6':[],'day7':[],'dpr7':[]}
#data/item 계층 밑의 값을 list으로 가져와 iteration
for i in root.findall('./data/item'):
    # item_name부터 텍스트를 가져와 딕셔너리에 저장
    for j in i:
        row_dict[j.tag].append(j.text)

df = pd.DataFrame(row_dict)
df.columns =  ['품목명','품목코드','품종명','품종코드','상태(상품, 중품)','상태코드',
'단위','일자(조회일자)','조회일자 가격','1일전 일자(조회일자 기준)','1일전 가격','1주일전 일자(조회일자 기준)'
,'1주일전 가격','2주일전 일자(조회일자 기준)','2주일전 가격','1개월전 일자(조회일자 기준)','1개월전 가격','1년전 일자(조회일자 기준)','1년전 가격','평년일자','평년 가격']

df
# Out:
#         품목명  품목코드     품종명 품종코드 상태(상품, 중품) 상태코드    단위    일자(조회일자) 조회일자 가격  \
# 0         소  4301      안심   21      1++등급   01  100g  당일 (09/15)  15,633
# 1         소  4301      안심   21       1+등급   02  100g  당일 (09/15)  15,794
# 2         소  4301      안심   21        1등급   03  100g  당일 (09/15)  13,059
# 3         소  4301      등심   22      1++등급   01  100g  당일 (09/15)  13,663
# 4         소  4301      등심   22       1+등급   02  100g  당일 (09/15)  12,857
# 5         소  4301      등심   22        1등급   03  100g  당일 (09/15)  10,140
# 6         소  4301      설도   36      1++등급   01  100g  당일 (09/15)   4,891
# 7         소  4301      설도   36       1+등급   02  100g  당일 (09/15)   4,804
# 8         소  4301      설도   36        1등급   03  100g  당일 (09/15)   4,121
# 9         소  4301      양지   40      1++등급   01  100g  당일 (09/15)   6,542
# 10        소  4301      양지   40       1+등급   02  100g  당일 (09/15)   6,159
# 11        소  4301      양지   40        1등급   03  100g  당일 (09/15)   5,528
# 12        소  4301      갈비   50      1++등급   01  100g  당일 (09/15)   8,174
# 13        소  4301      갈비   50       1+등급   02  100g  당일 (09/15)   6,831
# 14        소  4301      갈비   50        1등급   03  100g  당일 (09/15)   6,702
# 15       돼지  4304     앞다리   25        앞다리   00  100g  당일 (09/15)   1,403
# 16       돼지  4304     삼겹살   27        삼겹살   00  100g  당일 (09/15)   2,623
# 17       돼지  4304      갈비   28         갈비   00  100g  당일 (09/15)   1,535
# 18       돼지  4304      목심   68         목심   00  100g  당일 (09/15)   2,428
# 19   수입 소고기  4401      갈비   31        미국산   81  100g  당일 (09/15)   4,201
# 20   수입 소고기  4401      갈비   31        호주산   82  100g  당일 (09/15)   4,361
# 21   수입 소고기  4401     갈비살   37        미국산   81  100g  당일 (09/15)   4,426
# 22   수입 소고기  4401     갈비살   37        호주산   82  100g  당일 (09/15)       0
# 23  수입 돼지고기  4402     삼겹살   27        삼겹살   00  100g  당일 (09/15)   1,455
# 24        닭  9901  육계(kg)   99     육계(kg)   00   1kg  당일 (09/15)   5,588
# 25       계란  9903   특란10구   21        일반란   71   10구  당일 (09/15)   3,763
# 26       계란  9903   특란10구   21        등급란   72   10구  당일 (09/15)   5,339
# 27       계란  9903   특란30구   23        일반란   71   30구  당일 (09/15)   6,576
# 28       계란  9903   특란30구   23        등급란   72   30구  당일 (09/15)   8,552
# 29       우유  9908     흰우유   01        흰우유   00    1L  당일 (09/15)   2,713
#
#    1일전 일자(조회일자 기준)  ... 1주일전 일자(조회일자 기준) 1주일전 가격 2주일전 일자(조회일자 기준) 2주일전 가격  \
# 0      1일전 (09/14)  ...     1주일전 (09/08)  15,628     2주일전 (09/01)  16,758
# 1      1일전 (09/14)  ...     1주일전 (09/08)  15,766     2주일전 (09/01)  15,748
# 2      1일전 (09/14)  ...     1주일전 (09/08)  13,078     2주일전 (09/01)  13,010
# 3      1일전 (09/14)  ...     1주일전 (09/08)  13,625     2주일전 (09/01)  13,927
# 4      1일전 (09/14)  ...     1주일전 (09/08)  12,656     2주일전 (09/01)  12,375
# 5      1일전 (09/14)  ...     1주일전 (09/08)   9,986     2주일전 (09/01)   9,859
# 6      1일전 (09/14)  ...     1주일전 (09/08)   4,980     2주일전 (09/01)   5,432
# 7      1일전 (09/14)  ...     1주일전 (09/08)   4,901     2주일전 (09/01)   4,876
# 8      1일전 (09/14)  ...     1주일전 (09/08)   4,242     2주일전 (09/01)   4,246
# 9      1일전 (09/14)  ...     1주일전 (09/08)   6,574     2주일전 (09/01)   6,794
# 10     1일전 (09/14)  ...     1주일전 (09/08)   6,166     2주일전 (09/01)   6,164
# 11     1일전 (09/14)  ...     1주일전 (09/08)   5,516     2주일전 (09/01)   5,531
# 12     1일전 (09/14)  ...     1주일전 (09/08)   8,082     2주일전 (09/01)   7,152
# 13     1일전 (09/14)  ...     1주일전 (09/08)   6,960     2주일전 (09/01)   6,876
# 14     1일전 (09/14)  ...     1주일전 (09/08)   6,640     2주일전 (09/01)   6,647
# 15     1일전 (09/14)  ...     1주일전 (09/08)   1,382     2주일전 (09/01)   1,382
# 16     1일전 (09/14)  ...     1주일전 (09/08)   2,618     2주일전 (09/01)   2,813
# 17     1일전 (09/14)  ...     1주일전 (09/08)   1,488     2주일전 (09/01)   1,480
# 18     1일전 (09/14)  ...     1주일전 (09/08)   2,424     2주일전 (09/01)   2,615
# 19     1일전 (09/14)  ...     1주일전 (09/08)   4,093     2주일전 (09/01)   4,226
# 20     1일전 (09/14)  ...     1주일전 (09/08)   4,334     2주일전 (09/01)   4,319
# 21     1일전 (09/14)  ...     1주일전 (09/08)   4,405     2주일전 (09/01)   4,158
# 22     1일전 (09/14)  ...     1주일전 (09/08)       0     2주일전 (09/01)       0
# 23     1일전 (09/14)  ...     1주일전 (09/08)   1,452     2주일전 (09/01)   1,451
# 24     1일전 (09/14)  ...     1주일전 (09/08)   5,590     2주일전 (09/01)   5,601
# 25     1일전 (09/14)  ...     1주일전 (09/08)   3,828     2주일전 (09/01)   3,812
# 26     1일전 (09/14)  ...     1주일전 (09/08)   5,339     2주일전 (09/01)   5,324
# 27     1일전 (09/14)  ...     1주일전 (09/08)   6,583     2주일전 (09/01)   6,601
# 28     1일전 (09/14)  ...     1주일전 (09/08)   8,758     2주일전 (09/01)   9,293
# 29     1일전 (09/14)  ...     1주일전 (09/08)   2,715     2주일전 (09/01)   2,713
#
#    1개월전 일자(조회일자 기준) 1개월전 가격 1년전 일자(조회일자 기준) 1년전 가격 평년일자 평년 가격
# 0              1개월전  15,442             1년전      0  일평년     -
# 1              1개월전  15,796             1년전      0  일평년     -
# 2              1개월전  13,358             1년전      0  일평년     -
# 3              1개월전  13,990             1년전      0  일평년     -
# 4              1개월전  12,622             1년전      0  일평년     -
# 5              1개월전  10,272             1년전      0  일평년     -
# 6              1개월전   4,902             1년전      0  일평년     -
# 7              1개월전   5,255             1년전      0  일평년     -
# 8              1개월전   4,502             1년전      0  일평년     -
# 9              1개월전   5,973             1년전      0  일평년     -
# 10             1개월전   6,185             1년전      0  일평년     -
# 11             1개월전   5,450             1년전      0  일평년     -
# 12             1개월전   7,516             1년전      0  일평년     -
# 13             1개월전   6,977             1년전      0  일평년     -
# 14             1개월전   6,641             1년전      0  일평년     -
# 15             1개월전   1,301             1년전      0  일평년     -
# 16             1개월전   2,631             1년전      0  일평년     -
# 17             1개월전   1,382             1년전      0  일평년     -
# 18             1개월전   2,436             1년전      0  일평년     -
# 19             1개월전   4,213             1년전      0  일평년     -
# 20             1개월전   4,545             1년전      0  일평년     -
# 21             1개월전   4,388             1년전      0  일평년     -
# 22             1개월전       0             1년전      0  일평년     -
# 23             1개월전   1,471             1년전      0  일평년     -
# 24             1개월전   5,893             1년전      0  일평년     -
# 25             1개월전   3,676             1년전      0  일평년     -
# 26             1개월전   5,415             1년전      0  일평년     -
# 27             1개월전   6,626             1년전      0  일평년     -
# 28             1개월전   9,395             1년전      0  일평년     -
# 29             1개월전   2,709             1년전      0  일평년     -
#
# [30 rows x 21 columns]
